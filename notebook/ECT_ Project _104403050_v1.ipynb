# %% [markdown]
# # Preprocessing

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('104403050_data_new.csv')

# %%
#scratch the target columns into a sub-table 
val = data.iloc[:, 10:-1]
avg_val = val.sum(1)/len(val.columns)

# %%
#get the mean, then covert into true-false array(replaced by the assigned text.)
lbl_ =  (avg_val >= avg_val.mean())
lbl_.replace({True: 'Above-average Players', False: 'Below-average Players'}, inplace = True)

# %% [markdown]
# # Modeling:
#
# prework: Train test split
#
# models:
#
# 1. Naive Bayes
# 2. Decision Trees
# 3. Logistic Regression
# 4. SVM
#
# metrics required: accuracy, classification report, confusion matrix

# %%
#prework: spliting
from sklearn.model_selection import train_test_split
train_x, test_x, train_lbl, test_lbl = train_test_split(val, lbl_, test_size = 0.33, random_state = 1)

#prework: evaluation function
from sklearn import metrics
def metric(pred, label):X
    print("準確度:\n",metrics.accuracy_score(label, pred))
    print('\n分類報告:\n', metrics.classification_report(label, pred))
    print('\n混淆矩陣:\n', metrics.confusion_matrix(label, pred))
    print('\n')

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
nb = GaussianNB(priors = [0.005, 0.995])
nb.fit(train_x, train_lbl)
pred_nb = nb.predict(test_x)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(train_x, train_lbl)
pred_dt = dt.predict(test_x)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(train_x, train_lbl)
pred_lr = lr.predict(test_x)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.svm import SVC
svm = SVC(kernel = 'rbf', gamma = 'scale')
svm.fit(train_x, train_lbl)
pred_svm = svm.predict(test_x)

# %%
metric(test_lbl, pred_nb)
metric(test_lbl, pred_dt)
metric(test_lbl, pred_lr)
metric(test_lbl, pred_svm)
# Out:
# 準確度:
#  0.9085599866510929
#
# 分類報告:
#                         precision    recall  f1-score   support
#
# Above-average Players       0.97      0.88      0.92      3818
# Below-average Players       0.82      0.96      0.88      2175
#
#             micro avg       0.91      0.91      0.91      5993
#             macro avg       0.90      0.92      0.90      5993
#          weighted avg       0.92      0.91      0.91      5993
#
#
# 混淆矩陣:
#  [[3358  460]
#  [  88 2087]]
#
#
# 準確度:
#  0.9060570665776739
#
# 分類報告:
#                         precision    recall  f1-score   support
#
# Above-average Players       0.92      0.92      0.92      3437
# Below-average Players       0.89      0.89      0.89      2556
#
#             micro avg       0.91      0.91      0.91      5993
#             macro avg       0.90      0.90      0.90      5993
#          weighted avg       0.91      0.91      0.91      5993
#
#
# 混淆矩陣:
#  [[3160  277]
#  [ 286 2270]]
#
#
# 準確度:
#  0.9706324044718838
#
# 分類報告:
#                         precision    recall  f1-score   support
#
# Above-average Players       0.98      0.97      0.97      3500
# Below-average Players       0.95      0.98      0.97      2493
#
#             micro avg       0.97      0.97      0.97      5993
#             macro avg       0.97      0.97      0.97      5993
#          weighted avg       0.97      0.97      0.97      5993
#
#
# 混淆矩陣:
#  [[3385  115]
#  [  61 2432]]
#
#
# 準確度:
#  0.9941598531620224
#
# 分類報告:
#                         precision    recall  f1-score   support
#
# Above-average Players       1.00      0.99      0.99      3451
# Below-average Players       0.99      0.99      0.99      2542
#
#             micro avg       0.99      0.99      0.99      5993
#             macro avg       0.99      0.99      0.99      5993
#          weighted avg       0.99      0.99      0.99      5993
#
#
# 混淆矩陣:
#  [[3431   20]
#  [  15 2527]]

# %% [markdown]
# # KNN

# %%
#Keep the target's parameter records.
messi = data[data['Name'] == 'L. Messi'].iloc[:, 2:]
neymar = data[data['Name'] == 'Neymar Jr'].iloc[:, 2:]

# %%
data.drop('Unnamed: 0', 1, inplace = True)
data.drop('Name', 1, inplace = True)
from sklearn.model_selection import train_test_split

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(data, lbl_)   #Whole dataset
pred_knn = knn.predict(test_x2)

# %%
metric(test_lbl, pred_knn)
# Out:
# 準確度:
#  0.975304521942266
#
# 分類報告:
#                         precision    recall  f1-score   support
#
# Above-average Players       0.98      0.98      0.98      3466
# Below-average Players       0.97      0.97      0.97      2527
#
#             micro avg       0.98      0.98      0.98      5993
#             macro avg       0.97      0.98      0.97      5993
#          weighted avg       0.98      0.98      0.98      5993
#
#
# 混淆矩陣:
#  [[3382   84]
#  [  64 2463]]

# %%
n_top5 = knn.kneighbors(neymar, 6)
m_top5 = knn.kneighbors(messi, 6)

t = n_top5[1]
t = t.ravel()
t2 = m_top5[1]
t2 = t2.ravel()

# %%
#TOP 5 near NEYMAR in whole dataset
data.iloc[t]
# Out:
#     Unnamed: 0           Name  Age      Wage  Skill Moves  High  Medium  Low  \
# 2            2      Neymar Jr   26  10150000          5.0     1       1    0
# 13          13    David Silva   32   9975000          4.0     1       1    0
# 35          35        Marcelo   30   9975000          5.0     1       0    1
# 27          27       Casemiro   26   9975000          2.0     1       1    0
# 23          23      S. Agüero   30  10500000          4.0     1       1    0
# 33          33  P. Aubameyang   29   9275000          4.0     0       1    1
#
#     Height(cm)  Weight(kg)     ...      Penalties  Composure  Marking  \
# 2       175.26     68.0400     ...           81.0       94.0     27.0
# 13      172.72     67.1328     ...           75.0       93.0     59.0
# 35      175.26     79.8336     ...           59.0       86.0     71.0
# 27      185.42     83.9160     ...           66.0       84.0     88.0
# 23      172.72     69.8544     ...           83.0       90.0     30.0
# 33      187.96     79.8336     ...           76.0       86.0     27.0
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 2             24.0           33.0       9.0         9.0       15.0
# 13            53.0           29.0       6.0        15.0        7.0
# 35            85.0           86.0      12.0         5.0        5.0
# 27            90.0           87.0      13.0        14.0       16.0
# 23            20.0           12.0      13.0        15.0        6.0
# 33            25.0           36.0       6.0         9.0       15.0
#
#     GKPositioning  GKReflexes
# 2            15.0        11.0
# 13            6.0        12.0
# 35            5.0         9.0
# 27           12.0        12.0
# 23           11.0        14.0
# 33            9.0         9.0
#
# [6 rows x 44 columns]

# %%
data.iloc[t2]
# Out:
#     Unnamed: 0               Name  Age      Wage  Skill Moves  High  Medium  \
# 0            0           L. Messi   31  19775000          4.0     0       1
# 7            7          L. Suárez   31  15925000          3.0     1       1
# 6            6          L. Modrić   32  14700000          4.0     1       0
# 1            1  Cristiano Ronaldo   33  14175000          5.0     1       0
# 8            8       Sergio Ramos   32  13300000          3.0     1       1
# 36          36            G. Bale   28  12425000          4.0     1       1
#
#     Low  Height(cm)  Weight(kg)     ...      Penalties  Composure  Marking  \
# 0     0      170.18     72.1224     ...           75.0       96.0     33.0
# 7     0      182.88     86.1840     ...           85.0       85.0     62.0
# 6     0      172.72     66.2256     ...           82.0       84.0     60.0
# 1     1      187.96     83.0088     ...           85.0       95.0     28.0
# 8     0      182.88     82.1016     ...           75.0       82.0     87.0
# 36    0      185.42     82.1016     ...           76.0       86.0     54.0
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0             28.0           26.0       6.0        11.0       15.0
# 7             45.0           38.0      27.0        25.0       31.0
# 6             76.0           73.0      13.0         9.0        7.0
# 1             31.0           23.0       7.0        11.0       15.0
# 8             92.0           91.0      11.0         8.0        9.0
# 36            55.0           52.0      15.0        15.0       11.0
#
#     GKPositioning  GKReflexes
# 0            14.0         8.0
# 7            33.0        37.0
# 6            14.0         9.0
# 1            14.0        11.0
# 8             7.0        11.0
# 36            5.0         6.0
#
# [6 rows x 44 columns]
